# %% [markdown]
# # CS5841/EE5841 Final Project: Human Activity Recognition using Smartphone Sensor Data
#
# ### Sabina Bimbi, Noelle Haviland, Memory Mhembere
#
# This project uses...

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Loading and Exploration

# %% [markdown]
# ## Validation Split
# The data is already split into a train and test set. We will perform an additional 80-20(?) split on the training set to obtain a validation set.

# %% [markdown]
# ## Data Preprocessing
#
# Missing-value imputation? Scaling? Encoding?

# %% [markdown]
# ## Convolutional Neural Network (CNN)

# %% [markdown]
# ### CNN Compilation

# %% [markdown]
# ### CNN Training

# %% [markdown]
# ### CNN Evaluation

# %% [markdown]
# ## Long Short Term Memory (LSTM) Network

# %% [markdown]
# ### LSTM Compilation

# %% [markdown]
# ### LSTM Training

# %% [markdown]
# ### LSTM Evaluation

# %% [markdown]
# ## Combined CNN/LSTM

# %% [markdown]
# ### Combined Model Compilation

# %% [markdown]
# ### Combined Model Training

# %% [markdown]
# ### Combined Model Evaluation

# %% [markdown]
# ## Discussion and Conclusion

# %% [markdown]
# - Discussion
# - Conclusion
